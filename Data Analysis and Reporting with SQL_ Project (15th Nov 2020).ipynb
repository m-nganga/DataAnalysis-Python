# %% [markdown]
# # Data Analysis and Reporting with SQL: Project (15th November 2020)

# %% [markdown]
# ## Overview

# %% [markdown]
# Over the past few years, ride sharing apps have been on the rise across many cities in the world. While this has happened, Uber and Lyft's ride prices are not constant like public transport. They are greatly affected by the demand and supply of rides at a given time.
#
# As a Data Scientist working to understand this market, you have been tasked to come up with a **descriptive analysis report** to help a Ride Sharing Startup coming into the space, understand the various patterns on how pricing works for the existing ride sharing company.
#
# Luckily, you were able to access some real-time data from Uber & Lyft's API and weather data from a Weather API conditions.
# You build a custom application in Scala to query data at regular intervals and saved it to DynamoDB. The queried cab ride estimates are done after every 5 mins and weather data after every 1 hr.
#
# The cab ride data covers various types of cabs for Uber & Lyft and their price for the given location. Weather data contains weather attributes like temperature, rain, cloud, etc for all the locations taken into consideration.
#
# Now that you have your data in the given dataset, write SQL queries to perform descriptive analysis highlighting key insights that would be helpful for the startup in developing a new product.

# %% [markdown]
# ## Useful Information

# %% [markdown]
# Specific research question would then be : <em>**How do demand, supply as well as weather patterns affect cab pricing by Uber and Lyft?** </em>
#
# 1.   Metric for success : The main goal here is **to deduce factors affecting cab pricing** we will not be making any predictions and therefore we do not have a specific metric upon which to base our success. Success can be determined by whether or not we get to deduce useful relationships in the data that can help us understand the factors that influence cab pricing variations.
# 2.   Get started by asking, for instance, "When do prices hit a high during 3 periods of the day?" You get a feel of average pricing for a single day. You could select a random day and break it into periods of the day: early morning (5am - 10pm); mid morning (etc.) and afternoon (etc.).

# %% [markdown]
# ## Project Deliverable

# %% [markdown]
# The expected deliverable for this project will be an SQL notebook with your data analysis in SQL. You will need to create this notebook based on your understanding of the approaches that we've taken in previous workshop projects.

# %% [markdown]
# ## Dataset Explained

# %% [markdown]
# Weather Dataset URL = https://bit.ly/cabsweatherdata <br>
# Cabs Dataset URL = https://bit.ly/cabsdataset <br> <br>
#
# Cab Rides Dataset
# 1. distance: distance between source and destination.
# 2. cab_type: Uber or Lyft
# 3. time_stamp: time when data was queried
# 4. destination: destination of the ride
# 5. source: the starting point of the ride
# 6. price: price estimate for the ride in USD
# 7. surge_multiplier: the multiplier by which price was increased, default 1
# 8. unique identifier
# 9. product_id: uber/lyft identifier for cab-type
# 10. name: Visible type of the cab eg: Uber Pool, UberXL
#
# Weather Dataset
# 1. temp: Temperature
# 2. location: Location name
# 3. clouds: Clouds
# 4. pressure: pressure in mb
# 5. rain: rain in inches for the last hr
# 6. time_stamp: time when row data was collected
# 7. humidity: humidity in %
# 8. wind: wind speed in mph
#
# Project Source: https://bit.ly/2AKnlBL

# %% [markdown]
# ## Step 1. Pre-requisites

# %%
# Importing pandas library which will help in reading of data from an external 
#source as well and its manipulation.
import pandas as pd

# Loading SQL extension which will allow us to run SQL code in our Notebook.
# %load_ext sql

# Connecting to an in-memory SQLite database within colaboratory
# %sql sqlite://
# Out:
# 'Connected: @None'

# %% [markdown]
# ## Step 2. Preparing Datasets

# %% [markdown]
# ### Step 2.1 Importing Datasets

# %% [markdown]
# The dataset on cab rides

# %%
# Load the cab rides dataset from an external csv file and store it in a dataframe called cabs
cabs = pd.read_csv('https://bit.ly/cabsdataset')

# Store the dataset in our in memory sqlite database. but for controls, check 
# first if the table exists in the database, and if so drop it. 
# %sql DROP TABLE if EXISTS cabs

# Finally create an SQL table of our sqlite database and store 
# the recordset in readiness for further analysis with SQL 
# %sql PERSIST cabs;
# Out:
#  * sqlite://
# Done.
#  * sqlite://
# 'Persisted cabs'

# %% [markdown]
# The dataset on weather

# %%
# Load the weather dataset from an external csv file and store it in a dataframe "weather"
weather = pd.read_csv('https://bit.ly/cabsweatherdata')

#check for table existence and drop it accordingly.
# %sql DROP TABLE if EXISTS weather;

# Finally create an SQL table in the sqlite database running in memory and store 
# the recordset in readiness for further analysis with SQL 
# %sql PERSIST weather;
# Out:
#  * sqlite://
# Done.
#  * sqlite://
# 'Persisted weather'

# %% [markdown]
# ### Step 2.2 Exploratory Data Analysis

# %%
# sampling the cab rides dataset

# %sql SELECT * FROM cabs LIMIT 10;
# Out:
#  * sqlite://
# Done.
# [(0, 0, 0.44, 'Lyft', '2018-12-16 09:30:07.890', 'North Station', 'Haymarket Square', 5.0, 1.0, '424553bb-7174-41ea-aeb4-fe06d4f4b9d7', 'lyft_line', 'Shared'),
#  (1, 1, 0.44, 'Lyft', '2018-11-27 02:00:23.677', 'North Station', 'Haymarket Square', 11.0, 1.0, '4bd23055-6827-41c6-b23b-3c491f24e74d', 'lyft_premier', 'Lux'),
#  (2, 2, 0.44, 'Lyft', '2018-11-28 01:00:22.198', 'North Station', 'Haymarket Square', 7.0, 1.0, '981a3613-77af-4620-a42a-0c0866077d1e', 'lyft', 'Lyft'),
#  (3, 3, 0.44, 'Lyft', '2018-11-30 04:53:02.749', 'North Station', 'Haymarket Square', 26.0, 1.0, 'c2d88af2-d278-4bfd-a8d0-29ca77cc5512', 'lyft_luxsuv', 'Lux Black XL'),
#  (4, 4, 0.44, 'Lyft', '2018-11-29 03:49:20.223', 'North Station', 'Haymarket Square', 9.0, 1.0, 'e0126e1f-8ca9-4f2e-82b3-50505a09db9a', 'lyft_plus', 'Lyft XL'),
#  (5, 5, 0.44, 'Lyft', '2018-12-17 18:25:12.138', 'North Station', 'Haymarket Square', 16.5, 1.0, 'f6f6d7e4-3e18-4922-a5f5-181cdd3fa6f2', 'lyft_lux', 'Lux Black'),
#  (6, 6, 1.08, 'Lyft', '2018-11-26 05:03:00.200', 'Northeastern University', 'Back Bay', 10.5, 1.0, '462816a3-820d-408b-8549-0b39e82f65ac', 'lyft_plus', 'Lyft XL'),
#  (7, 7, 1.08, 'Lyft', '2018-12-02 19:53:04.677', 'Northeastern University', 'Back Bay', 16.5, 1.0, '474d6376-bc59-4ec9-bf57-4e6d6faeb165', 'lyft_lux', 'Lux Black'),
#  (8, 8, 1.08, 'Lyft', '2018-12-03 06:28:02.645', 'Northeastern University', 'Back Bay', 3.0, 1.0, '4f9fee41-fde3-4767-bbf1-a00e108701fb', 'lyft_line', 'Shared'),
#  (9, 9, 1.08, 'Lyft', '2018-11-27 10:45:22.249', 'Northeastern University', 'Back Bay', 27.5, 1.0, '8612d909-98b8-4454-a093-30bd48de0cb3', 'lyft_luxsuv', 'Lux Black XL')]

# %%
# sampling the weather dataset

# %sql SELECT * FROM weather LIMIT 5;
# Out:
#  * sqlite://
# Done.
# [(0, 0, 42.42, 'Back Bay', 1.0, 1012.14, 0.1228, '2018-12-16 23:45:01', 0.77, 11.25),
#  (1, 1, 42.43, 'Beacon Hill', 1.0, 1012.15, 0.1846, '2018-12-16 23:45:01', 0.76, 11.32),
#  (2, 2, 42.5, 'Boston University', 1.0, 1012.15, 0.1089, '2018-12-16 23:45:01', 0.76, 11.07),
#  (3, 3, 42.11, 'Fenway', 1.0, 1012.13, 0.0969, '2018-12-16 23:45:01', 0.77, 11.09),
#  (4, 4, 43.13, 'Financial District', 1.0, 1012.14, 0.1786, '2018-12-16 23:45:01', 0.75, 11.49)]

# %%
#we seek to know the number of records that exist for each of the datasets.

# %sql SELECT COUNT(*) FROM cabS;
# Out:
#  * sqlite://
# Done.
# [(693071,)]

# %%
# %sql SELECT COUNT (*) FROM weather;
# Out:
#  * sqlite://
# Done.
# [(6276,)]

# %% [markdown]
#  There are a total of `693,071` records of cab rides in the dataset, while we have `6,276` weather records. To note is that the queried cab ride estimates were done after every 5 mins while those of weather records were done every hour.

# %%
# let us determine the time period of the data that we use for analysis.
# pick the cab ride records based on time to determine the start and end of data collection.
# start  time stamp for the collection of cab rides data.

# %%sql SELECT * , datetime(time_stamp) as TIME_STAMP1 from cabs
ORDER BY datetime(time_stamp) ASC
LIMIT 4;
# Out:
#  * sqlite://
# Done.
# [(10462, 10462, 2.4, 'Lyft', '2018-11-26 03:40:46.972', 'Beacon Hill', 'Fenway', 19.5, 1.25, 'c241e674-57c8-4b00-bcbb-f1f59a98fac5', 'lyft_plus', 'Lyft XL', '2018-11-26 03:40:46'),
#  (13895, 13895, 2.01, 'Lyft', '2018-11-26 03:40:46.527', 'South Station', 'North Station', 16.5, 1.0, '65e9134a-dff4-45b9-81e3-90ba4cae702f', 'lyft_premier', 'Lux', '2018-11-26 03:40:46'),
#  (23285, 23285, 4.32, 'Lyft', '2018-11-26 03:40:46.528', 'Northeastern University', 'Financial District', 22.5, 1.0, '716f939f-56eb-425a-b125-64246b8e9907', 'lyft_plus', 'Lyft XL', '2018-11-26 03:40:46'),
#  (29102, 29102, 1.16, 'Uber', '2018-11-26 03:40:46.421', 'Theatre District', 'Haymarket Square', None, 1.0, '63fbb593-95ba-4b74-88d1-e3eb0d99fe33', '8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a', 'Taxi', '2018-11-26 03:40:46')]

# %%
# end time stamp for the collection of cab rides data.

# %%sql SELECT * , datetime(time_stamp) as TIME_STAMP1 from cabs
ORDER BY datetime(time_stamp) DESC
LIMIT 4;
# Out:
#  * sqlite://
# Done.
# [(10350, 10350, 4.55, 'Uber', '2018-12-18 19:15:10.579', 'Financial District', 'Northeastern University', 30.5, 1.0, '9d29a29d-4d8f-44c4-b400-621b4f33301b', '6c84fd89-3f11-4782-9b50-97c468b19529', 'Black', '2018-12-18 19:15:10'),
#  (17138, 17138, 3.91, 'Uber', '2018-12-18 19:15:10.603', 'Financial District', 'Boston University', 12.0, 1.0, '7273d46d-3270-43ef-9fbc-c218f45c3496', '997acbb5-e102-41e1-b155-9df7de0a73f2', 'UberPool', '2018-12-18 19:15:10'),
#  (17871, 17871, 0.46, 'Lyft', '2018-12-18 19:15:10.762', 'South Station', 'Financial District', 3.0, 1.0, 'e0497e3a-3ddc-4ee9-aeec-0a539315d42b', 'lyft_line', 'Shared', '2018-12-18 19:15:10'),
#  (18039, 18039, 2.48, 'Uber', '2018-12-18 19:15:10.943', 'South Station', 'Beacon Hill', 14.0, 1.0, 'e7ff1618-2d8b-4d13-a798-593858064a9e', '6f72dfc5-27f1-42e8-84db-ccc7a75f6969', 'UberXL', '2018-12-18 19:15:10')]

# %%
# weather records... Earliest data stamp.

# %%sql 
SELECT * , strftime('%Y-%m-%d %H:%M:%f', time_stamp) as new_time from weather
ORDER BY datetime(strftime('%Y-%m-%d %H:%M:%f', time_stamp)) ASC
LIMIT 5;
# Out:
#  * sqlite://
# Done.
# [(2509, 2509, 40.98, 'Haymarket Square', 0.87, 1014.4, None, '2018-11-26 03:40:44', 0.92, 1.57, '2018-11-26 03:40:44.000'),
#  (2510, 2510, 40.81, 'Northeastern University', 0.89, 1014.35, None, '2018-11-26 03:40:44', 0.93, 1.36, '2018-11-26 03:40:44.000'),
#  (2511, 2511, 40.86, 'South Station', 0.87, 1014.39, None, '2018-11-26 03:40:44', 0.93, 1.6, '2018-11-26 03:40:44.000'),
#  (2512, 2512, 40.84, 'West End', 0.87, 1014.4, None, '2018-11-26 03:40:44', 0.93, 1.52, '2018-11-26 03:40:44.000'),
#  (3998, 3998, 41.04, 'Back Bay', 0.87, 1014.39, None, '2018-11-26 03:40:45', 0.92, 1.46, '2018-11-26 03:40:45.000')]

# %%
# weather records... end data stamp for data collection.

# %%sql 
SELECT * , strftime('%Y-%m-%d %H:%M:%f', time_stamp) as new_time from weather
ORDER BY datetime(strftime('%Y-%m-%d %H:%M:%f', time_stamp)) DESC
LIMIT 5;
# Out:
#  * sqlite://
# Done.
# [(483, 483, 30.8, 'Beacon Hill', 0.0, 1012.32, None, '2018-12-18 18:45:02', 0.46, 13.08, '2018-12-18 18:45:02.000'),
#  (484, 484, 30.96, 'Boston University', 0.0, 1012.35, None, '2018-12-18 18:45:02', 0.45, 12.93, '2018-12-18 18:45:02.000'),
#  (485, 485, 30.93, 'Fenway', 0.0, 1012.35, None, '2018-12-18 18:45:02', 0.45, 12.99, '2018-12-18 18:45:02.000'),
#  (486, 486, 31.19, 'Financial District', 0.0, 1012.31, None, '2018-12-18 18:45:02', 0.45, 13.18, '2018-12-18 18:45:02.000'),
#  (487, 487, 30.83, 'North Station', 0.0, 1012.32, None, '2018-12-18 18:45:02', 0.46, 13.09, '2018-12-18 18:45:02.000')]

# %% [markdown]
# Data in these recordsets was collected between 2018-11-26 03:40:46 and 2018-12-18 19:15:10 for the cab rides and between 2018-11-26 03:40:44 and 2018-12-18 18:45:02 for the weather. Any insights obtained therefore are based on this period of business transactions.

# %%
# checking for NULL values. in my preliminary examination of the datasets using MS Excel, I was able to determine
# that cab rides had NULL values in the price column. Weather dataset too has some NULL entries in the  "rain" field.
# I interpret this to mean no rain and so will populate these with zeros.

# %%sql 
SELECT *  FROM weather
WHERE rain ISNULL
LIMIT 4;
# Out:
#  * sqlite://
# Done.
# [(11, 11, 43.28, 'Back Bay', 0.81, 990.81, None, '2018-11-27 19:45:20', 0.71, 8.3),
#  (12, 12, 43.27, 'Beacon Hill', 0.8, 990.8, None, '2018-11-27 19:45:20', 0.71, 8.3),
#  (13, 13, 43.35, 'Boston University', 0.82, 990.82, None, '2018-11-27 19:45:20', 0.71, 8.24),
#  (14, 14, 43.07, 'Fenway', 0.82, 990.82, None, '2018-11-27 19:45:20', 0.72, 8.28)]

# %%
# count of NULL records.

# %%sql
SELECT COUNT (*) as [No. of NULL] FROM weather
WHERE rain ISNULL;
# Out:
#  * sqlite://
# Done.
# [(5382,)]

# %%
# Update the NULLS to zeros in the rain column

# %%sql
UPDATE weather
SET rain = 0
WHERE rain ISNULL;
# Out:
#  * sqlite://
# 5382 rows affected.
# []

# %%
# checking on the records with NULL in cab rides dataset.

# %%sql 
SELECT * FROM cabs
WHERE price ISNULL
LIMIT 5;
# Out:
#  * sqlite://
# Done.
# [(18, 18, 1.11, 'Uber', '2018-12-01 14:13:04.211', 'West End', 'North End', None, 1.0, 'fa5fb705-03a0-4eb9-82d9-7fe80872f754', '8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a', 'Taxi'),
#  (31, 31, 2.48, 'Uber', '2018-12-02 23:52:56.318', 'South Station', 'Beacon Hill', None, 1.0, 'eee70d94-6706-4b95-a8ce-0e34f0fa8f37', '8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a', 'Taxi'),
#  (40, 40, 2.94, 'Uber', '2018-11-29 20:38:05.298', 'Fenway', 'North Station', None, 1.0, '7f47ff53-7cf2-4a6a-8049-83c90e042593', '8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a', 'Taxi'),
#  (60, 60, 1.16, 'Uber', '2018-12-13 20:10:16.318', 'West End', 'North End', None, 1.0, '43abdbe4-ab9e-4f39-afdc-31cfa375dc25', '8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a', 'Taxi'),
#  (69, 69, 2.67, 'Uber', '2018-11-30 13:08:03.653', 'Beacon Hill', 'North End', None, 1.0, '80db1c49-9d51-4575-a4f4-1ec23b4d3e31', '8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a', 'Taxi')]

# %%
# checking the nature of these records.. from which company they are etc.

# %%sql
SELECT DISTINCT cab_type FROM cabs
WHERE price ISNULL;
# Out:
#  * sqlite://
# Done.
# [('Uber',)]

# %%
# we notice that all records where prices have not been updated are from Uber and we need to know the count.

# %%sql
SELECT COUNT(cab_type) FROM cabs
WHERE price ISNULL;
# Out:
#  * sqlite://
# Done.
# [(55095,)]

# %%
# determine the total number of Uber records so as to see if the NULLS are significant.

# %%sql 
SELECT COUNT(cab_type) FROM cabs
WHERE cab_type = "Uber";
# Out:
#  * sqlite://
# Done.
# [(385663,)]

# %%
# drop all the records where the price is NULL as the price feature is important in our analysis.

# %%sql
DELETE FROM cabs
WHERE price ISNULL;
# Out:
#  * sqlite://
# 55095 rows affected.
# []

# %% [markdown]
#  From this check of null values, we notice that:
# 1.  Out of 6,273 records in the weather dataset, we have 5,382 records for days / time when there was no rain. we update all the NULL values to zeros in the rain column for these records to mean there was 0 mm of rain (it didn't rain)
# 2. The price feature of cab rides registered null values of `55,095` entries. Pricing is one of the most important feature of the dataset in this analysis and therefore these will be dropped as they represent only 14% of all Uber records in the dataset.
#
#
# **After this exercise, we now have a clean set of datasets that we can use for our analysis.**

# %% [markdown]
# ## Step 3. Business Needs
# Our main interest is to interogate the available data so as to deduce any useful relationships, if any, between the dataset features that can help us understand the factors that influence cab pricing variations. <br> Rephrasing this into a research question: **"How does uber and lyft vary their cab pricing in relation to demand and supply?"**

# %% [markdown]
# **1. How many distinct cab types are reported on and further, among these cab types, which is the mode type?**

# %%
#We make use of the property 'cab_type' and use the COUNT()function against this 
#variable for each of its make group. 

# %%sql 
SELECT cab_type, count(cab_type) as 'frequency'
FROM cabs
GROUP BY cab_type
ORDER BY count(cab_type) DESC;
# Out:
#  * sqlite://
# Done.
# [('Uber', 330568), ('Lyft', 307408)]

# %% [markdown]
# `Uber` cars are preferred over `Lyft` ones at a share of `51.81%` to `48.19%` of the sampled rides respectively.

# %% [markdown]
# ---

# %% [markdown]
# **2. Get the feel of the charges by picking the highest cost of a ride, min cost and the average cab ride and further, select the top 15 ride records in terms of travel cost ordered by the cab type then by cost so that we know the other associated details like the car type, distance etc.**

# %%
#highest registered charge for a ride
# %%sql
select *, max(price)
from cabs
# Out:
#  * sqlite://
# Done.
# [(597071, 597071, 4.43, 'Lyft', '2018-12-02 01:28:02.123', 'Fenway', 'Financial District', 97.5, 2.0, 'ba1593a1-e4fd-4c7a-a011-e2d4fccbf081', 'lyft_luxsuv', 'Lux Black XL', 97.5)]

# %%
#lowest registered charge for a ride

# %%sql
select *, min(price)
from cabs
# Out:
#  * sqlite://
# Done.
# [(5901, 5901, 1.53, 'Lyft', '2018-11-28 23:33:41.778', 'Back Bay', 'Boston University', 2.5, 1.0, 'f6ed86e6-c3f1-42f5-9ce9-bb4bea19f18e', 'lyft_line', 'Shared', 2.5)]

# %%
#Average cost for a ride.

# %%sql
SELECT avg(price)
FROM cabs
# Out:
#  * sqlite://
# Done.
# [(16.545125490614065,)]

# %% [markdown]
#  From the above exploration, we notice the following:
# 1. The highest price for a ride recorded is by Lyft for the journey between Financial District and Fenway at a cost of `$97.5` (with a multiplier of 2.0) on 2nd Dec 2018.
# 2.  The lowest price for a ride recorded is also by Lyft for the journey between Boston University and Back Bay at a cost of `$2.5` (default price, no multiplier) on 28th Dec 2018.
# 3. The average cost for the rides is `$16.54`.

# %%
# get the average price for rides between distinct source/destination pairs.

# %%sql
SELECT "source" ||" - " || "destination" as route, distance, cast(price as float) as price, AVG(price)
FROM cabs
GROUP BY route
ORDER BY AVG(price) DESC;
# Out:
#  * sqlite://
# Done.
# [('Financial District - Boston University', 5.42, 47.5, 25.498434004474273),
#  ('Boston University - Financial District', 4.72, 13.0, 24.146085011185683),
#  ('Fenway - Financial District', 4.4, 19.5, 23.438817855540602),
#  ('Financial District - Fenway', 4.58, 19.5, 23.404849910394265),
#  ('Northeastern University - Financial District', 3.79, 11.5, 22.582093757043047),
#  ('Financial District - Northeastern University', 4.13, 9.0, 21.918583671628326),
#  ('Theatre District - Boston University', 3.07, 13.5, 20.360661724626624),
#  ('Boston University - North Station', 3.39, 26.0, 20.185337915234822),
#  ('Northeastern University - North Station', 3.22, 11.0, 19.910938903863432),
#  ('Fenway - North Station', 3.07, 11.0, 19.701839464882944),
#  ('North End - Back Bay', 2.88, 19.5, 19.55093477799023),
#  ('North Station - Northeastern University', 3.37, 36.0, 19.537848158131176),
#  ('Back Bay - North End', 7.36, 25.5, 19.473018908009347),
#  ('South Station - Back Bay', 3.27, 26.0, 19.103822314049587),
#  ('Theatre District - Fenway', 3.11, 32.5, 19.06927781698424),
#  ('West End - Northeastern University', 3.42, 38.5, 18.96496924128503),
#  ('North Station - Boston University', 3.18, 27.5, 18.9315578465063),
#  ('Boston University - Theatre District', 2.92, 10.5, 18.689557444953127),
#  ('Boston University - West End', 3.04, 16.5, 18.611765989958524),
#  ('North Station - Fenway', 3.05, 16.5, 18.547603121516165),
#  ('Fenway - Theatre District', 2.67, 22.5, 18.2327221438646),
#  ('Northeastern University - West End', 2.83, 34.0, 18.204155266757866),
#  ('Fenway - West End', 2.8, 16.5, 18.161805555555556),
#  ('West End - Boston University', 2.8, 18.0, 18.157164700742683),
#  ('Back Bay - Haymarket Square', 2.32, 9.5, 17.987384023534737),
#  ('West End - Fenway', 2.84, 10.5, 17.932692307692307),
#  ('Back Bay - South Station', 3.45, 9.5, 17.700710683172858),
#  ('Boston University - Beacon Hill', 3.23, 10.0, 17.315535124941064),
#  ('South Station - Beacon Hill', 2.5, 15.5, 17.276303698598667),
#  ('Theatre District - Northeastern University', 3.13, 19.5, 16.91075050709939),
#  ('Haymarket Square - Back Bay', 2.04, 28.5, 16.86048879837067),
#  ('Northeastern University - Beacon Hill', 2.44, 16.5, 16.84243273542601),
#  ('Fenway - Beacon Hill', 2.43, 13.5, 16.796673572744016),
#  ('Beacon Hill - Northeastern University', 1.92, 8.0, 16.47179228353522),
#  ('Beacon Hill - Boston University', 2.31, 7.0, 16.37673733804476),
#  ('Beacon Hill - Fenway', 2.32, 8.5, 16.158839779005525),
#  ('Northeastern University - Theatre District', 1.91, 7.0, 16.144805048456163),
#  ('North End - Beacon Hill', 1.79, 8.5, 15.98262987012987),
#  ('Beacon Hill - South Station', 2.48, 13.0, 15.950660539919587),
#  ('South Station - West End', 1.71, 27.0, 15.881171786120591),
#  ('South Station - North Station', 1.84, 27.5, 15.746735517568851),
#  ('North Station - South Station', 1.34, 8.0, 15.374198146828226),
#  ('Beacon Hill - North End', 1.87, 15.0, 15.270941558441558),
#  ('Theatre District - Haymarket Square', 1.61, 27.0, 15.204973027646663),
#  ('North End - Theatre District', 1.41, 8.5, 15.169406392694064),
#  ('Theatre District - North End', 1.7, 27.5, 15.159646118721462),
#  ('West End - South Station', 2.14, 15.0, 15.018254781420765),
#  ('Back Bay - Boston University', 1.41, 8.0, 14.03939184519696),
#  ('Boston University - Back Bay', 1.56, 13.0, 13.992801197880672),
#  ('South Station - Theatre District', 1.12, 5.0, 13.95257949744274),
#  ('Fenway - Back Bay', 1.45, 3.0, 13.80215497478221),
#  ('Beacon Hill - Haymarket Square', 1.35, 12.0, 13.799136559872757),
#  ('Northeastern University - Back Bay', 1.64, 14.0, 13.698922902494331),
#  ('Haymarket Square - Theatre District', 1.16, 7.5, 13.677272215339565),
#  ('Back Bay - Fenway', 1.62, 13.5, 13.658752007341134),
#  ('North End - West End', 1.35, 27.5, 13.49487270155587),
#  ('North End - Financial District', 1.04, 8.5, 13.417597115608281),
#  ('West End - North End', 1.0, 10.0, 13.370016513328615),
#  ('Haymarket Square - Beacon Hill', 0.91, 7.0, 13.33855941831402),
#  ('Financial District - Haymarket Square', 0.99, 13.5, 13.188208811233789),
#  ('Financial District - North End', 1.0, 34.0, 13.179634798790417),
#  ('Back Bay - Northeastern University', 1.22, 7.5, 13.151040226628895),
#  ('North Station - North End', 1.08, 6.5, 13.10664053493198),
#  ('Theatre District - South Station', 0.55, 7.0, 12.888925950633755),
#  ('North End - North Station', 1.0, 7.0, 12.824092219020173),
#  ('West End - Haymarket Square', 0.69, 11.0, 12.771290360873694),
#  ('Haymarket Square - Financial District', 0.99, 27.0, 12.731618435155413),
#  ('North Station - Haymarket Square', 0.7, 7.0, 12.57179054054054),
#  ('Haymarket Square - West End', 0.66, 5.0, 12.529855175688509),
#  ('South Station - Financial District', 0.54, 6.5, 12.436910006293266),
#  ('Financial District - South Station', 0.39, 7.0, 12.349066498846234),
#  ('Haymarket Square - North Station', 0.49, 6.5, 12.332544512057696)]

# %% [markdown]
#  The above information on average pricing will help the incoming ride company to estimate the pricing between different sources and destinations.

# %%
# %%sql
# SELECT cab_type, name,  "source" ||" - " || "destination" as route, distance, time_stamp, cast(price as float) as price_f, id, product_id
# FROM cabs
# ORDER BY price_f DESC
# LIMIT 10;
# Out:
#  * sqlite://
# Done.
# [('Lyft', 'Lux Black XL', 'Financial District - Fenway', 4.43, '2018-12-02 01:28:02.123', 97.5, 'ba1593a1-e4fd-4c7a-a011-e2d4fccbf081', 'lyft_luxsuv'),
#  ('Lyft', 'Lux Black XL', 'Fenway - Financial District', 3.89, '2018-11-28 21:41:35.635', 92.0, 'edb9ba13-b129-487f-be93-2e3abdd700a3', 'lyft_luxsuv'),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 3.75, '2018-12-13 17:15:14.374', 92.0, 'e0032a2b-c328-457e-adb5-79c3d83064a8', 'lyft_luxsuv'),
#  ('Lyft', 'Lux Black XL', 'Financial District - Boston University', 5.39, '2018-11-29 01:02:08.714', 92.0, '6f17623a-f97c-4379-9188-4f3e07d1c48e', 'lyft_luxsuv'),
#  ('Lyft', 'Lux Black XL', 'Financial District - Boston University', 5.39, '2018-11-27 22:03:21.754', 92.0, 'fe9f56b5-e54a-48b4-b702-4e625adcf0ab', 'lyft_luxsuv'),
#  ('Lyft', 'Lux Black XL', 'Financial District - Boston University', 5.36, '2018-12-17 23:45:13.982', 92.0, '16373de7-5ef0-45a7-86d8-842bd12780e9', 'lyft_luxsuv'),
#  ('Lyft', 'Lux Black XL', 'Financial District - Boston University', 5.37, '2018-12-01 20:07:59.927', 92.0, '2a3f4de9-7a24-4580-8079-a7953a1431e3', 'lyft_luxsuv'),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 3.75, '2018-11-27 17:03:22.477', 92.0, '75c1c9bf-38a7-4cb6-81c1-e2effaaaedbd', 'lyft_luxsuv'),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 4.39, '2018-12-14 03:40:07.486', 92.0, 'fa0c51a4-acc0-4c49-8244-561e9ad945e3', 'lyft_luxsuv'),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 4.37, '2018-12-16 06:00:05.181', 92.0, '71ad1473-ebc6-4b98-80c6-0f56046af3e2', 'lyft_luxsuv')]

# %%
# We intend to find out the relationship between the cost of the ride and the cab type
# and also the time of the day that these trips happen.

# %%sql
SELECT cab_type, name,  "source" ||" - " || "destination" as route, distance, time_stamp, cast(price as float) as price, id, product_id, surge_multiplier
FROM cabs
ORDER BY price DESC
LIMIT 100;
# Out:
#  * sqlite://
# Done.
# [('Lyft', 'Lux Black XL', 'Financial District - Fenway', 4.43, '2018-12-02 01:28:02.123', 97.5, 'ba1593a1-e4fd-4c7a-a011-e2d4fccbf081', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Fenway - Financial District', 3.89, '2018-11-28 21:41:35.635', 92.0, 'edb9ba13-b129-487f-be93-2e3abdd700a3', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 3.75, '2018-12-13 17:15:14.374', 92.0, 'e0032a2b-c328-457e-adb5-79c3d83064a8', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Financial District - Boston University', 5.39, '2018-11-29 01:02:08.714', 92.0, '6f17623a-f97c-4379-9188-4f3e07d1c48e', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Financial District - Boston University', 5.39, '2018-11-27 22:03:21.754', 92.0, 'fe9f56b5-e54a-48b4-b702-4e625adcf0ab', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Financial District - Boston University', 5.36, '2018-12-17 23:45:13.982', 92.0, '16373de7-5ef0-45a7-86d8-842bd12780e9', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Financial District - Boston University', 5.37, '2018-12-01 20:07:59.927', 92.0, '2a3f4de9-7a24-4580-8079-a7953a1431e3', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 3.75, '2018-11-27 17:03:22.477', 92.0, '75c1c9bf-38a7-4cb6-81c1-e2effaaaedbd', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 4.39, '2018-12-14 03:40:07.486', 92.0, 'fa0c51a4-acc0-4c49-8244-561e9ad945e3', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 4.37, '2018-12-16 06:00:05.181', 92.0, '71ad1473-ebc6-4b98-80c6-0f56046af3e2', 'lyft_luxsuv', 2.0),
#  ('Uber', 'Black SUV', 'Financial District - Northeastern University', 7.46, '2018-11-30 17:53:01.274', 89.5, '5374b432-8695-430c-8a43-da2b778137a4', '6d318bcc-22a3-4af6-bddd-b409bfce1546', 1.0),
#  ('Lyft', 'Lux Black XL', 'Fenway - Financial District', 4.24, '2018-11-28 21:32:07.999', 89.0, '3958e0d4-bc3f-4148-9c92-0c711f4b9474', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 4.53, '2018-12-14 04:40:11.556', 89.0, '025b4780-6aa7-4b1b-bba4-84f373f99116', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Theatre District - Boston University', 4.64, '2018-12-14 14:45:11.214', 89.0, 'f5203125-b2fa-4e47-a072-0f85d48146f6', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Fenway - Financial District', 3.36, '2018-12-18 07:10:14.491', 89.0, 'a6b9bfaa-667c-40aa-9795-c4c4f7a55034', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Fenway - Financial District', 3.36, '2018-11-28 11:20:08.073', 89.0, '0768844d-d5ab-4f88-a1fc-1f2ef02eedcf', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 4.07, '2018-12-17 14:55:12.050', 89.0, '015983d3-5ebc-4378-914a-de31423bc50c', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Theatre District - Boston University', 4.96, '2018-12-14 08:50:09.859', 89.0, '58107779-327f-482c-9572-ab0c8ebbba26', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Financial District - Boston University', 5.11, '2018-12-15 01:10:11.866', 89.0, 'bf6a442b-d853-4460-abd3-2c663dc20c86', 'lyft_luxsuv', 1.75),
#  ('Lyft', 'Lux Black XL', 'Financial District - Boston University', 5.41, '2018-12-16 03:35:13.936', 89.0, 'f3b0063b-262f-460e-ac50-f20a225adc45', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 4.37, '2018-11-30 00:33:01.462', 89.0, 'cabcac57-8bb5-48ef-9e04-8f8b7f37ed3a', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Financial District - Boston University', 5.4, '2018-12-03 11:02:59.033', 89.0, 'd50188ac-bf4d-4eed-bb0f-45b8f33c27ac', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Theatre District - Boston University', 4.78, '2018-12-18 12:40:09.516', 87.5, '46e35c38-d89d-451c-97cd-aec7ce6136ce', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 4.53, '2018-12-17 18:30:10.317', 87.5, 'a33a47db-9612-4bf7-9c9d-839140f93fa6', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Fenway - Financial District', 4.27, '2018-12-01 11:22:56.538', 87.5, '8338dbd3-875d-44ba-a7c7-c6dcb44fe564', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Fenway - Financial District', 4.25, '2018-12-15 08:50:03.445', 87.5, 'de775f16-94e1-4da8-a400-3364ebc1ad85', 'lyft_luxsuv', 2.0),
#  ('Uber', 'Black SUV', 'Financial District - Boston University', 5.56, '2018-12-14 17:45:04.040', 87.0, '79b05217-c0b1-4d58-bab0-2896b4a94de4', '6d318bcc-22a3-4af6-bddd-b409bfce1546', 1.0),
#  ('Uber', 'Black SUV', 'Financial District - Boston University', 4.44, '2018-11-29 01:29:08.548', 81.5, '1572d487-54e9-4bdf-8742-632410689a22', '6d318bcc-22a3-4af6-bddd-b409bfce1546', 1.0),
#  ('Lyft', 'Lux Black XL', 'Fenway - Financial District', 3.42, '2018-11-30 06:33:03.080', 80.5, '9ecd7da0-02ec-4f20-9f6f-034cf0bdca15', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Fenway - North Station', 3.68, '2018-11-30 10:43:01.018', 80.5, '2f8676e3-69e1-4c92-b19b-0f3ccd35ce44', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 3.82, '2018-12-16 20:20:11.135', 80.5, 'ed98960b-77d0-4f76-94c2-85c470c7d7c0', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Northeastern University - North Station', 3.28, '2018-11-29 12:18:03.087', 80.5, 'ce40dcab-e420-4de8-b9c4-7bd6c6e5666c', 'lyft_luxsuv', 2.0),
#  ('Uber', 'Black SUV', 'North Station - Northeastern University', 3.37, '2018-12-18 07:20:11.972', 80.5, '03dae9c1-8adb-41d0-adac-0e201301a358', '6d318bcc-22a3-4af6-bddd-b409bfce1546', 1.0),
#  ('Lyft', 'Lux Black XL', 'Northeastern University - Financial District', 4.03, '2018-12-18 08:40:05.884', 80.5, '2c3fd77b-f039-4449-be0e-188a8c545a7f', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Northeastern University - Financial District', 4.14, '2018-11-28 14:29:08.529', 80.5, '959c0ae0-80dd-484b-9e78-7d397ec1af68', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Northeastern University - Financial District', 3.06, '2018-12-16 06:20:08.877', 80.5, 'ab07ee87-1192-465a-804e-d46b3f777cf0', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Northeastern University - North Station', 3.27, '2018-12-02 10:48:03.978', 80.5, 'eb4e29d1-ede6-4dcf-9022-e560017f5b99', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Fenway - Financial District', 5.86, '2018-12-17 17:55:03.496', 80.5, '97c6fc58-a8f7-48ad-81d1-33a11c5ad8cd', 'lyft_luxsuv', 1.5),
#  ('Lyft', 'Lux Black XL', 'Fenway - Financial District', 4.14, '2018-12-16 04:20:13.167', 80.5, '8d5bc466-0db4-4f32-9c6c-b0b279fed12c', 'lyft_luxsuv', 1.75),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 4.4, '2018-11-27 21:57:22.361', 80.5, 'f5d56839-6c28-4187-97c4-360538a797a2', 'lyft_luxsuv', 1.75),
#  ('Lyft', 'Lux Black XL', 'Northeastern University - Financial District', 3.01, '2018-11-30 14:33:07.551', 80.5, 'de57fcc9-78b6-4f28-ae8f-1fde5a9ebcb5', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Financial District - Fenway', 4.56, '2018-12-14 07:25:04.994', 80.5, 'ccf1f623-14c8-4e88-a96b-175006a0bd73', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - North Station', 3.46, '2018-11-29 13:08:02.185', 80.5, '1d23d573-189d-4696-aeb9-a28133bda945', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Northeastern University - North Station', 3.74, '2018-12-02 18:23:02.082', 80.5, '6c4b8ddc-8f46-47d4-ac07-a8ff7e96924e', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 4.46, '2018-11-28 18:11:25.933', 80.5, '6ad8ce21-a70a-4e58-8e6e-5af41e523598', 'lyft_luxsuv', 1.75),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 4.75, '2018-12-17 02:15:05.497', 80.5, '5a5dd141-9c4c-4d34-8c6d-040fa6a7b110', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Fenway - North Station', 3.23, '2018-12-13 16:45:12.149', 80.5, 'b28c27aa-a6e0-4f95-930c-be4b32cfadcf', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Financial District - Boston University', 5.39, '2018-11-27 05:06:22.265', 80.5, 'd9f21d28-6fa1-417c-abe6-a4c1a180cf3a', 'lyft_luxsuv', 1.75),
#  ('Lyft', 'Lux Black XL', 'Fenway - Financial District', 4.18, '2018-11-28 13:31:26.678', 80.5, 'fb9d9caf-aee9-433d-96c5-79e318b47b61', 'lyft_luxsuv', 1.75),
#  ('Lyft', 'Lux Black XL', 'Boston University - North Station', 3.41, '2018-12-17 07:35:04.127', 80.0, 'dc847868-563b-462d-8b12-921969b872f0', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Theatre District - Boston University', 4.7, '2018-12-01 03:42:59.013', 80.0, 'bcecebbf-cc8b-42bf-960f-4bd3bf596357', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Theatre District - Boston University', 4.77, '2018-12-15 20:45:10.885', 80.0, '8f11a831-07db-412f-9c8f-eb600645789b', 'lyft_luxsuv', 1.75),
#  ('Lyft', 'Lux Black XL', 'Theatre District - Boston University', 4.77, '2018-12-02 06:13:02.119', 80.0, '054c2c21-7f34-48fd-a0a8-b03c223516a9', 'lyft_luxsuv', 1.75),
#  ('Lyft', 'Lux Black XL', 'Northeastern University - Financial District', 4.22, '2018-11-26 20:20:10.233', 80.0, '2a9d8e73-187c-4d9f-81b8-678d0484537b', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Northeastern University - North Station', 3.76, '2018-12-04 05:48:03.634', 80.0, 'a36a86b4-b327-48fc-acbc-157720514d5e', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - North Station', 3.44, '2018-11-28 13:32:07.682', 80.0, 'e38343aa-fc89-44aa-b410-a6432e496adb', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Northeastern University - West End', 3.22, '2018-12-14 04:35:10.153', 80.0, 'fa6833e1-d432-4d6f-9009-52c58f415a23', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Northeastern University - North Station', 3.27, '2018-12-01 08:43:02.790', 80.0, 'd5f39ae0-9c09-4b6c-b84c-4657830cd683', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 4.5, '2018-12-18 06:50:07.848', 80.0, 'b457f883-5e7b-421d-ab71-bd8435bda9a6', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Northeastern University - Financial District', 3.05, '2018-12-01 11:58:00.700', 80.0, '463f6da8-c7c6-43bc-80f8-3257237e677a', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Theatre District - Fenway', 4.44, '2018-12-17 11:30:07.437', 80.0, '7ecd8cf6-ceb7-49f5-8730-d36f0e4403e4', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Theatre District - Boston University', 4.79, '2018-11-30 05:12:57.590', 80.0, '865e4da3-f911-45fa-b61a-f119a9713f85', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Theatre District - Boston University', 4.96, '2018-11-29 19:43:00.370', 80.0, '49614b2d-3a31-487e-844d-e1ef813d196f', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Fenway - Financial District', 3.42, '2018-11-30 17:08:01.898', 80.0, '5c6d94c7-2bc1-4dfb-a2b0-07cebc3baf13', 'lyft_luxsuv', 1.75),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 4.43, '2018-11-27 21:09:22.103', 80.0, '4f34e1cc-d7c6-4378-a237-81b689793659', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Financial District - Fenway', 4.47, '2018-11-29 07:52:57.415', 80.0, '54f2fd26-b7c5-4bb6-8cc5-65d4563dbc9b', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Fenway - Financial District', 4.33, '2018-12-18 02:30:10.013', 80.0, '1618f70a-5fea-4a4b-b376-d69bcb663229', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 4.47, '2018-12-17 07:10:09.846', 80.0, 'c92a9d6c-d2ca-4fa4-9e6e-fc2aeb2cdb6f', 'lyft_luxsuv', 1.75),
#  ('Lyft', 'Lux Black XL', 'Theatre District - Fenway', 4.57, '2018-12-01 21:32:56.389', 80.0, 'a914f6f8-291c-4877-a968-eade5918c5a0', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 4.75, '2018-12-02 06:53:03.314', 80.0, '118d3672-d94b-47fe-98b0-b45f099bc60f', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - North Station', 3.46, '2018-12-02 07:23:01.829', 80.0, '255b9f8f-4e1f-4509-bd1f-807982a6403e', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 4.39, '2018-12-02 01:23:01.527', 80.0, '26261d7f-8fc0-46c2-8f2c-a6b5d1ac811a', 'lyft_luxsuv', 1.75),
#  ('Lyft', 'Lux Black XL', 'Theatre District - Boston University', 4.95, '2018-11-27 00:09:14.143', 80.0, '0d3a37ea-ed85-4255-8108-b5cab8ccfc0b', 'lyft_luxsuv', 1.75),
#  ('Lyft', 'Lux Black XL', 'Financial District - Fenway', 4.53, '2018-12-14 23:00:13.530', 80.0, '9cb49821-3558-426b-b41c-3496e284acd2', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 3.7, '2018-12-18 00:40:03.402', 80.0, '75563d8f-bc75-47fe-9c64-ec7551b4d789', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Fenway - Financial District', 4.34, '2018-11-26 23:12:16.269', 80.0, 'e01ba666-6481-4e1b-90d4-e13c398818da', 'lyft_luxsuv', 1.75),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 4.54, '2018-11-28 17:11:24.531', 80.0, '76e7c416-3068-44b5-b0e4-9c1936af683f', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Fenway - North Station', 3.24, '2018-12-02 14:18:01.669', 80.0, '9a5e868d-7603-4684-9ce3-81151bf88779', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Theatre District - Boston University', 4.45, '2018-12-18 11:30:09.106', 80.0, '6815ff7b-035c-4118-accc-b4b186c3e355', 'lyft_luxsuv', 1.75),
#  ('Lyft', 'Lux Black XL', 'Theatre District - Boston University', 4.45, '2018-11-30 20:37:56.118', 80.0, '3c67ffb0-e60e-4634-b454-7fb2823f1436', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - North Station', 3.45, '2018-11-29 00:44:07.898', 80.0, 'b2cdb725-4dd2-4911-ab7c-f0516c251a27', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - North Station', 3.45, '2018-11-26 19:17:09.793', 80.0, 'faa8f0fc-3a2d-469b-9c77-4de1443351d2', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Northeastern University - Financial District', 3.93, '2018-12-03 18:02:58.439', 80.0, '572db775-ac65-4546-a827-e6b51da33e87', 'lyft_luxsuv', 1.75),
#  ('Lyft', 'Lux Black XL', 'Fenway - Financial District', 4.16, '2018-12-17 11:55:10.049', 80.0, 'd1a4c5a9-ce30-4d19-bbba-f5fe69927e29', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Northeastern University - Financial District', 3.01, '2018-11-28 15:02:09.361', 80.0, '1b723b07-f690-4ff7-8e76-f7144f56b04a', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Financial District - Fenway', 4.6, '2018-11-28 09:47:08.105', 80.0, '94834ccf-1e4c-4de0-981c-a17902c6f9b1', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Theatre District - Boston University', 4.72, '2018-12-13 03:45:07.100', 80.0, '4a298be4-6458-4580-a6a8-cb1a1fe9cdbb', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - North Station', 3.44, '2018-11-27 09:27:22.418', 80.0, 'bf210c9c-ad9c-4eeb-9cb5-2b770b7bad5a', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Theatre District - Fenway', 4.27, '2018-12-14 18:45:16.128', 80.0, '25b5e1a2-8ea7-4217-bc3a-216fa7d14c44', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - Financial District', 4.53, '2018-11-29 03:19:16.830', 80.0, '0b2022ee-ffb5-46b9-b922-8f13b216fc4b', 'lyft_luxsuv', 1.75),
#  ('Lyft', 'Lux Black XL', 'Theatre District - Boston University', 4.71, '2018-12-02 01:18:02.560', 80.0, '2a4830ec-e2cb-42f2-b840-fb8a9134e272', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Theatre District - Boston University', 3.08, '2018-12-17 04:05:03.479', 80.0, '6a5c44eb-0cb3-4c68-8358-fca59dbd4e00', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Northeastern University - Financial District', 3.95, '2018-12-18 02:20:10.204', 80.0, '533d682d-375e-4cbf-ac5c-a7b22663ee53', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Theatre District - Boston University', 4.79, '2018-12-14 21:10:10.280', 80.0, 'b06754a3-1d47-4208-8a71-f6ecae3dbc72', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Northeastern University - Financial District', 2.99, '2018-12-01 11:58:03.151', 80.0, 'f23fc2ce-6f30-4771-ac82-1a60461c220d', 'lyft_luxsuv', 2.0),
#  ('Uber', 'Black SUV', 'Theatre District - Boston University', 5.46, '2018-11-30 20:57:56.509', 76.0, '06737463-52f4-428d-87f6-52e81b2d42ed', '6d318bcc-22a3-4af6-bddd-b409bfce1546', 1.0),
#  ('Uber', 'UberXL', 'Fenway - Financial District', 4.41, '2018-11-26 17:53:09.563', 76.0, 'e7a55158-b1d2-4a06-b0d6-ae9429c2be50', '6f72dfc5-27f1-42e8-84db-ccc7a75f6969', 1.0),
#  ('Lyft', 'Lux Black XL', 'Boston University - West End', 3.01, '2018-11-28 12:44:08.808', 75.0, '171b0827-8658-4bff-8ffa-f27980837ac9', 'lyft_luxsuv', 2.0),
#  ('Lyft', 'Lux Black XL', 'Northeastern University - Financial District', 3.98, '2018-12-03 22:33:00.810', 75.0, 'f28cc556-171d-404f-985a-b9299f62d1cd', 'lyft_luxsuv', 1.75),
#  ('Lyft', 'Lux Black XL', 'Fenway - Theatre District', 2.48, '2018-11-27 00:45:25.569', 75.0, 'c9353187-1d3e-4c12-92b8-9d09b87ebe6b', 'lyft_luxsuv', 2.0)]

# %% [markdown]
# Regardless of the distance, `94%` of the highest rates (Top 100) for the rides were recorded by lyft. Also notice that among the top 100 rides in terms of cost, all the Lyft rides' prices were hiked some to  double double the cost. This send another probing question... does Uber ever increase its prices?... lets find out next.  </font></em>

# %% [markdown]
# ---

# %% [markdown]
# **3. Does Uber ever increase its prices? How about Lyft?**

# %%
# %%sql
# SELECT cab_type, name, product_id, "source" ||" - " || "destination" as route, distance, time_stamp, cast(price as float), surge_multiplier
# FROM cabs
# WHERE price <> 'None' AND cab_type = "Uber" AND surge_multiplier > 1
# ORDER BY price DESC
# LIMIT 5
# Out:
#  * sqlite://
# Done.
# []

# %% [markdown]
# ---

# %%
# %%sql
# SELECT cab_type, name, product_id, "source" ||" - " || "destination" as route, distance, time_stamp, cast(price as float), surge_multiplier
# FROM cabs
# WHERE price <> 'None' AND cab_type = "Lyft" AND surge_multiplier > 1
# ORDER BY price DESC
# Limit 20
# Out:
#  * sqlite://
# Done.
# [('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Financial District - Fenway', 4.43, '2018-12-02 01:28:02.123', 97.5, 2.0),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Fenway - Financial District', 3.89, '2018-11-28 21:41:35.635', 92.0, 2.0),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Boston University - Financial District', 3.75, '2018-12-13 17:15:14.374', 92.0, 2.0),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Financial District - Boston University', 5.39, '2018-11-29 01:02:08.714', 92.0, 2.0),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Financial District - Boston University', 5.39, '2018-11-27 22:03:21.754', 92.0, 2.0),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Financial District - Boston University', 5.36, '2018-12-17 23:45:13.982', 92.0, 2.0),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Financial District - Boston University', 5.37, '2018-12-01 20:07:59.927', 92.0, 2.0),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Boston University - Financial District', 3.75, '2018-11-27 17:03:22.477', 92.0, 2.0),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Boston University - Financial District', 4.39, '2018-12-14 03:40:07.486', 92.0, 2.0),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Boston University - Financial District', 4.37, '2018-12-16 06:00:05.181', 92.0, 2.0),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Fenway - Financial District', 4.24, '2018-11-28 21:32:07.999', 89.0, 2.0),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Boston University - Financial District', 4.53, '2018-12-14 04:40:11.556', 89.0, 2.0),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Theatre District - Boston University', 4.64, '2018-12-14 14:45:11.214', 89.0, 2.0),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Fenway - Financial District', 3.36, '2018-12-18 07:10:14.491', 89.0, 2.0),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Fenway - Financial District', 3.36, '2018-11-28 11:20:08.073', 89.0, 2.0),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Boston University - Financial District', 4.07, '2018-12-17 14:55:12.050', 89.0, 2.0),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Theatre District - Boston University', 4.96, '2018-12-14 08:50:09.859', 89.0, 2.0),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Financial District - Boston University', 5.11, '2018-12-15 01:10:11.866', 89.0, 1.75),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Financial District - Boston University', 5.41, '2018-12-16 03:35:13.936', 89.0, 2.0),
#  ('Lyft', 'Lux Black XL', 'lyft_luxsuv', 'Boston University - Financial District', 4.37, '2018-11-30 00:33:01.462', 89.0, 2.0)]

# %%
#How many categories of price hikes are there?

# %%sql
SELECT DISTINCT surge_multiplier
FROM cabs;
# Out:
#  * sqlite://
# Done.
# [(1.0,), (1.25,), (2.5,), (2.0,), (1.75,), (1.5,), (3.0,)]

# %% [markdown]
# Interestingly, we notice that `Uber` does not increase its prices for the rides at all. This is brought out by the fact that the surge_multiplier is always 1. However, `Lyft` on the other hand has some rides with normal fare and others with hiked charges with between 1.25 to 3 times normal fare. </font></em>

# %%
# Do we have any special / common property about the rides whose fare is hiked by three times?

# %%sql
SELECT cab_type, name, product_id, "source" ||" - " || "destination" as route, distance, time_stamp, cast(price as float), surge_multiplier
FROM cabs
WHERE surge_multiplier = 3
ORDER BY route DESC;
# Out:
#  * sqlite://
# Done.
# [('Lyft', 'Lyft XL', 'lyft_plus', 'Theatre District - Boston University', 4.64, '2018-11-27 22:12:23.100', 62.5, 3.0),
#  ('Lyft', 'Lyft', 'lyft', 'Theatre District - Boston University', 4.64, '2018-12-16 23:40:18.739', 38.0, 3.0),
#  ('Lyft', 'Lyft XL', 'lyft_plus', 'Boston University - Financial District', 4.39, '2018-11-27 04:42:21.898', 65.0, 3.0),
#  ('Lyft', 'Lyft', 'lyft', 'Boston University - Financial District', 4.39, '2018-12-14 03:40:07.486', 38.5, 3.0),
#  ('Lyft', 'Lyft XL', 'lyft_plus', 'Beacon Hill - Boston University', 2.33, '2018-12-01 13:57:58.833', 42.5, 3.0),
#  ('Lyft', 'Lyft', 'lyft', 'Beacon Hill - Boston University', 2.33, '2018-12-01 13:57:58.833', 26.0, 3.0),
#  ('Lyft', 'Lyft', 'lyft', 'Back Bay - South Station', 1.84, '2018-11-27 09:03:21.922', 22.5, 3.0),
#  ('Lyft', 'Lyft XL', 'lyft_plus', 'Back Bay - South Station', 1.84, '2018-12-17 03:05:03.672', 38.0, 3.0),
#  ('Lyft', 'Lyft XL', 'lyft_plus', 'Back Bay - North End', 3.16, '2018-11-28 12:32:08.522', 55.0, 3.0),
#  ('Lyft', 'Lyft', 'lyft', 'Back Bay - North End', 3.16, '2018-11-28 12:32:08.522', 27.5, 3.0),
#  ('Lyft', 'Lyft XL', 'lyft_plus', 'Back Bay - Haymarket Square', 2.3, '2018-11-27 16:54:22.045', 42.5, 3.0),
#  ('Lyft', 'Lyft', 'lyft', 'Back Bay - Haymarket Square', 2.3, '2018-11-27 16:54:22.045', 26.0, 3.0)]

# %% [markdown]
#  We notice that the only routes where the prices are hiked by up to 3 time are only 6. and this happens only with the Lyft and Lyft Plus products of the company. The incoming company needs to know the special feature that is along these routes for proper placement.

# %% [markdown]
# **4. How many car types / categories do the two companies have, and does this have any relationship with the cost of the ride?**

# %%
# Use the COUNT() function to get the total number of cab subcategories for all the 
# rides registered.
# %%sql
SELECT cab_type, name, COUNT(name) as 'Frequency'
FROM cabs
GROUP BY name
# Out:
#  * sqlite://
# Done.
# [('Uber', 'Black', 55095),
#  ('Uber', 'Black SUV', 55096),
#  ('Lyft', 'Lux', 51235),
#  ('Lyft', 'Lux Black', 51235),
#  ('Lyft', 'Lux Black XL', 51235),
#  ('Lyft', 'Lyft', 51235),
#  ('Lyft', 'Lyft XL', 51235),
#  ('Lyft', 'Shared', 51233),
#  ('Uber', 'UberPool', 55091),
#  ('Uber', 'UberX', 55094),
#  ('Uber', 'UberXL', 55096),
#  ('Uber', 'WAV', 55096)]

# %%
# Get the favourite car make by route

# %%sql
SELECT "source" ||" - " || "destination" as route, name, COUNT(name) as [car name popularity]
FROM cabs
GROUP BY route
ORDER BY route DESC
Limit 100
# Out:
#  * sqlite://
# Done.
# [('West End - South Station', 'UberXL', 8784),
#  ('West End - Northeastern University', 'Lux Black XL', 8778),
#  ('West End - North End', 'UberPool', 8478),
#  ('West End - Haymarket Square', 'Lux', 8424),
#  ('West End - Fenway', 'UberX', 9360),
#  ('West End - Boston University', 'UberXL', 9156),
#  ('Theatre District - South Station', 'UberX', 8994),
#  ('Theatre District - Northeastern University', 'Lyft XL', 8874),
#  ('Theatre District - North End', 'Lux Black XL', 8760),
#  ('Theatre District - Haymarket Square', 'Black SUV', 8898),
#  ('Theatre District - Fenway', 'Lux Black XL', 8502),
#  ('Theatre District - Boston University', 'Shared', 9173),
#  ('South Station - West End', 'Black SUV', 8790),
#  ('South Station - Theatre District', 'Shared', 8994),
#  ('South Station - North Station', 'Black SUV', 8424),
#  ('South Station - Financial District', 'UberX', 9534),
#  ('South Station - Beacon Hill', 'UberPool', 8706),
#  ('South Station - Back Bay', 'Lux Black', 8712),
#  ('Northeastern University - West End', 'Lux Black XL', 8772),
#  ('Northeastern University - Theatre District', 'UberPool', 8874),
#  ('Northeastern University - North Station', 'WAV', 8904),
#  ('Northeastern University - Financial District', 'UberX', 8874),
#  ('Northeastern University - Beacon Hill', 'Lux', 8920),
#  ('Northeastern University - Back Bay', 'UberXL', 8820),
#  ('North Station - South Station', 'UberX', 8418),
#  ('North Station - Northeastern University', 'Black SUV', 8904),
#  ('North Station - North End', 'UberPool', 8674),
#  ('North Station - Haymarket Square', 'Lyft', 8880),
#  ('North Station - Fenway', 'UberXL', 8970),
#  ('North Station - Boston University', 'Lux Black', 8730),
#  ('North End - West End', 'Black SUV', 8484),
#  ('North End - Theatre District', 'WAV', 8760),
#  ('North End - North Station', 'Lyft', 8675),
#  ('North End - Financial District', 'WAV', 8598),
#  ('North End - Beacon Hill', 'UberPool', 9240),
#  ('North End - Back Bay', 'Lyft XL', 9414),
#  ('Haymarket Square - West End', 'Shared', 8424),
#  ('Haymarket Square - Theatre District', 'WAV', 8879),
#  ('Haymarket Square - North Station', 'UberPool', 8874),
#  ('Haymarket Square - Financial District', 'Black SUV', 9330),
#  ('Haymarket Square - Beacon Hill', 'WAV', 8802),
#  ('Haymarket Square - Back Bay', 'Black SUV', 8838),
#  ('Financial District - South Station', 'WAV', 9534),
#  ('Financial District - Northeastern University', 'Shared', 8868),
#  ('Financial District - North End', 'Lux Black XL', 8598),
#  ('Financial District - Haymarket Square', 'Lux', 9329),
#  ('Financial District - Fenway', 'Lyft', 8928),
#  ('Financial District - Boston University', 'Lux Black XL', 8940),
#  ('Fenway - West End', 'Lyft XL', 9360),
#  ('Fenway - Theatre District', 'Lux Black', 8508),
#  ('Fenway - North Station', 'WAV', 8970),
#  ('Fenway - Financial District', 'UberXL', 8916),
#  ('Fenway - Beacon Hill', 'Lyft XL', 8688),
#  ('Fenway - Back Bay', 'Shared', 8724),
#  ('Boston University - West End', 'UberXL', 9162),
#  ('Boston University - Theatre District', 'Lyft', 9174),
#  ('Boston University - North Station', 'Black', 8730),
#  ('Boston University - Financial District', 'UberX', 8940),
#  ('Boston University - Beacon Hill', 'UberPool', 8484),
#  ('Boston University - Back Bay', 'UberXL', 8682),
#  ('Beacon Hill - South Station', 'UberXL', 8705),
#  ('Beacon Hill - Northeastern University', 'UberPool', 8916),
#  ('Beacon Hill - North End', 'UberXL', 9240),
#  ('Beacon Hill - Haymarket Square', 'UberXL', 8802),
#  ('Beacon Hill - Fenway', 'UberPool', 8688),
#  ('Beacon Hill - Boston University', 'Shared', 8490),
#  ('Back Bay - South Station', 'UberPool', 8724),
#  ('Back Bay - Northeastern University', 'UberX', 8825),
#  ('Back Bay - North End', 'UberXL', 9414),
#  ('Back Bay - Haymarket Square', 'WAV', 8838),
#  ('Back Bay - Fenway', 'Lyft XL', 8718),
#  ('Back Bay - Boston University', 'WAV', 8682)]

# %% [markdown]
#  The schedule shows which cars are popular in which routes. This will help the incoming company judge the cards to employ on which routes.

# %% [markdown]
# **5. How does Uber's rate compare to that of Lyft for the same distance and also at the same time?**

# %%
# %%sql
# SELECT cab_type, name, "source" ||" - " || "destination" as route, distance, time_stamp, cast(price as float) as price, surge_multiplier, product_id
# FROM cabs
# WHERE price <> 'None'
# ORDER BY route, distance DESC
# Limit 100
# Out:
#  * sqlite://
# Done.
# [('Lyft', 'Shared', 'Back Bay - Boston University', 1.78, '2018-11-27 19:18:21.869', 5.0, 1.0, 'lyft_line'),
#  ('Lyft', 'Lyft XL', 'Back Bay - Boston University', 1.78, '2018-11-27 19:18:21.869', 13.5, 1.0, 'lyft_plus'),
#  ('Lyft', 'Lux Black', 'Back Bay - Boston University', 1.78, '2018-11-30 12:22:55.867', 19.5, 1.0, 'lyft_lux'),
#  ('Lyft', 'Lux Black XL', 'Back Bay - Boston University', 1.78, '2018-11-30 12:22:55.867', 26.0, 1.0, 'lyft_luxsuv'),
#  ('Lyft', 'Lyft', 'Back Bay - Boston University', 1.78, '2018-11-30 12:22:55.867', 9.0, 1.0, 'lyft'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.78, '2018-11-30 12:22:55.867', 16.5, 1.0, 'lyft_premier'),
#  ('Lyft', 'Lyft', 'Back Bay - Boston University', 1.77, '2018-11-30 03:03:00.720', 9.0, 1.0, 'lyft'),
#  ('Lyft', 'Lux Black XL', 'Back Bay - Boston University', 1.77, '2018-11-30 13:43:01.082', 27.5, 1.0, 'lyft_luxsuv'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.77, '2018-11-30 13:43:01.082', 16.5, 1.0, 'lyft_premier'),
#  ('Lyft', 'Lux Black', 'Back Bay - Boston University', 1.77, '2018-11-30 13:43:01.082', 19.5, 1.0, 'lyft_lux'),
#  ('Lyft', 'Shared', 'Back Bay - Boston University', 1.77, '2018-11-30 13:43:01.082', 5.0, 1.0, 'lyft_line'),
#  ('Lyft', 'Lyft XL', 'Back Bay - Boston University', 1.77, '2018-11-30 13:43:01.082', 13.5, 1.0, 'lyft_plus'),
#  ('Lyft', 'Lyft XL', 'Back Bay - Boston University', 1.73, '2018-12-02 17:28:03.371', 13.5, 1.0, 'lyft_plus'),
#  ('Lyft', 'Lux Black', 'Back Bay - Boston University', 1.73, '2018-12-16 22:30:10.431', 19.5, 1.0, 'lyft_lux'),
#  ('Lyft', 'Lux Black XL', 'Back Bay - Boston University', 1.73, '2018-12-16 22:30:10.431', 27.5, 1.0, 'lyft_luxsuv'),
#  ('Lyft', 'Shared', 'Back Bay - Boston University', 1.73, '2018-12-16 22:30:10.431', 5.0, 1.0, 'lyft_line'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.73, '2018-12-16 22:30:10.431', 16.5, 1.0, 'lyft_premier'),
#  ('Lyft', 'Lyft', 'Back Bay - Boston University', 1.73, '2018-12-16 22:30:10.431', 9.0, 1.0, 'lyft'),
#  ('Lyft', 'Lyft', 'Back Bay - Boston University', 1.72, '2018-11-27 09:48:22.393', 10.5, 1.25, 'lyft'),
#  ('Lyft', 'Lux Black', 'Back Bay - Boston University', 1.72, '2018-12-14 10:10:08.997', 22.5, 1.25, 'lyft_lux'),
#  ('Lyft', 'Shared', 'Back Bay - Boston University', 1.72, '2018-12-14 10:10:08.997', 7.0, 1.0, 'lyft_line'),
#  ('Lyft', 'Lyft XL', 'Back Bay - Boston University', 1.72, '2018-12-14 10:10:08.997', 13.5, 1.25, 'lyft_plus'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.72, '2018-12-14 10:10:08.997', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux Black XL', 'Back Bay - Boston University', 1.72, '2018-12-14 10:10:08.997', 32.5, 1.25, 'lyft_luxsuv'),
#  ('Lyft', 'Lux Black XL', 'Back Bay - Boston University', 1.72, '2018-11-28 16:02:08.424', 26.0, 1.0, 'lyft_luxsuv'),
#  ('Lyft', 'Lyft', 'Back Bay - Boston University', 1.72, '2018-11-28 16:02:08.424', 9.0, 1.0, 'lyft'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.72, '2018-12-18 07:10:14.982', 16.5, 1.0, 'lyft_premier'),
#  ('Lyft', 'Shared', 'Back Bay - Boston University', 1.72, '2018-12-18 07:10:14.982', 5.0, 1.0, 'lyft_line'),
#  ('Lyft', 'Lyft XL', 'Back Bay - Boston University', 1.72, '2018-12-18 07:10:14.982', 13.5, 1.0, 'lyft_plus'),
#  ('Lyft', 'Lux Black', 'Back Bay - Boston University', 1.72, '2018-12-18 07:10:14.982', 19.5, 1.0, 'lyft_lux'),
#  ('Lyft', 'Lyft XL', 'Back Bay - Boston University', 1.71, '2018-12-02 11:48:04.614', 13.5, 1.0, 'lyft_plus'),
#  ('Lyft', 'Lux Black', 'Back Bay - Boston University', 1.71, '2018-12-04 00:23:05.118', 19.5, 1.0, 'lyft_lux'),
#  ('Lyft', 'Lyft', 'Back Bay - Boston University', 1.71, '2018-12-17 06:25:07.738', 7.0, 1.0, 'lyft'),
#  ('Lyft', 'Lux Black XL', 'Back Bay - Boston University', 1.71, '2018-11-28 18:26:24.712', 27.5, 1.0, 'lyft_luxsuv'),
#  ('Lyft', 'Shared', 'Back Bay - Boston University', 1.71, '2018-11-27 00:39:14.691', 5.0, 1.0, 'lyft_line'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.71, '2018-12-02 03:03:02.385', 13.5, 1.0, 'lyft_premier'),
#  ('Lyft', 'Lyft', 'Back Bay - Boston University', 1.71, '2018-11-29 01:18:40.764', 9.0, 1.25, 'lyft'),
#  ('Lyft', 'Lux Black', 'Back Bay - Boston University', 1.71, '2018-11-29 01:18:40.764', 22.5, 1.25, 'lyft_lux'),
#  ('Lyft', 'Lyft XL', 'Back Bay - Boston University', 1.71, '2018-11-29 01:18:40.764', 13.5, 1.25, 'lyft_plus'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.71, '2018-11-29 01:18:40.764', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Shared', 'Back Bay - Boston University', 1.71, '2018-11-29 01:18:40.764', 7.0, 1.0, 'lyft_line'),
#  ('Lyft', 'Lux Black XL', 'Back Bay - Boston University', 1.71, '2018-11-29 01:18:40.764', 34.0, 1.25, 'lyft_luxsuv'),
#  ('Lyft', 'Lyft XL', 'Back Bay - Boston University', 1.71, '2018-12-02 06:08:00.925', 13.5, 1.0, 'lyft_plus'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.71, '2018-12-02 06:08:00.925', 16.5, 1.0, 'lyft_premier'),
#  ('Lyft', 'Lux Black XL', 'Back Bay - Boston University', 1.71, '2018-12-13 23:00:14.559', 26.0, 1.0, 'lyft_luxsuv'),
#  ('Lyft', 'Lux Black', 'Back Bay - Boston University', 1.71, '2018-12-13 23:00:14.559', 19.5, 1.0, 'lyft_lux'),
#  ('Lyft', 'Shared', 'Back Bay - Boston University', 1.71, '2018-12-13 23:00:14.559', 5.0, 1.0, 'lyft_line'),
#  ('Lyft', 'Lyft', 'Back Bay - Boston University', 1.71, '2018-12-13 23:00:14.559', 9.0, 1.0, 'lyft'),
#  ('Lyft', 'Lyft XL', 'Back Bay - Boston University', 1.71, '2018-11-30 01:07:57.670', 13.5, 1.0, 'lyft_plus'),
#  ('Lyft', 'Lyft', 'Back Bay - Boston University', 1.71, '2018-11-30 01:07:57.670', 7.0, 1.0, 'lyft'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.71, '2018-11-30 01:07:57.670', 13.5, 1.0, 'lyft_premier'),
#  ('Lyft', 'Shared', 'Back Bay - Boston University', 1.71, '2018-11-30 01:07:57.670', 5.0, 1.0, 'lyft_line'),
#  ('Lyft', 'Lux Black XL', 'Back Bay - Boston University', 1.71, '2018-11-30 01:07:57.670', 27.5, 1.0, 'lyft_luxsuv'),
#  ('Lyft', 'Lux Black', 'Back Bay - Boston University', 1.71, '2018-11-30 01:07:57.670', 19.5, 1.0, 'lyft_lux'),
#  ('Lyft', 'Shared', 'Back Bay - Boston University', 1.7, '2018-12-01 03:02:59.933', 7.0, 1.0, 'lyft_line'),
#  ('Lyft', 'Lyft XL', 'Back Bay - Boston University', 1.7, '2018-12-01 03:02:59.933', 16.5, 1.25, 'lyft_plus'),
#  ('Lyft', 'Lux Black XL', 'Back Bay - Boston University', 1.7, '2018-12-18 00:25:03.783', 38.5, 1.25, 'lyft_luxsuv'),
#  ('Lyft', 'Lyft', 'Back Bay - Boston University', 1.7, '2018-12-18 00:25:03.783', 10.5, 1.25, 'lyft'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.7, '2018-12-18 00:25:03.783', 19.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux Black', 'Back Bay - Boston University', 1.7, '2018-12-18 00:25:03.783', 27.5, 1.25, 'lyft_lux'),
#  ('Lyft', 'Lyft', 'Back Bay - Boston University', 1.69, '2018-12-16 23:40:15.195', 7.0, 1.0, 'lyft'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.69, '2018-12-16 23:40:15.195', 13.5, 1.0, 'lyft_premier'),
#  ('Lyft', 'Lux Black XL', 'Back Bay - Boston University', 1.69, '2018-12-16 23:40:15.195', 26.0, 1.0, 'lyft_luxsuv'),
#  ('Lyft', 'Lux Black', 'Back Bay - Boston University', 1.69, '2018-11-28 18:16:25.138', 19.5, 1.0, 'lyft_lux'),
#  ('Lyft', 'Shared', 'Back Bay - Boston University', 1.69, '2018-11-28 18:16:25.138', 5.0, 1.0, 'lyft_line'),
#  ('Lyft', 'Lyft XL', 'Back Bay - Boston University', 1.69, '2018-11-28 18:16:25.138', 13.5, 1.0, 'lyft_plus'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.69, '2018-11-28 16:26:07.939', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux Black', 'Back Bay - Boston University', 1.69, '2018-12-13 11:30:12.596', 22.5, 1.25, 'lyft_lux'),
#  ('Lyft', 'Lyft', 'Back Bay - Boston University', 1.69, '2018-12-13 11:30:12.596', 10.5, 1.25, 'lyft'),
#  ('Lyft', 'Lyft XL', 'Back Bay - Boston University', 1.69, '2018-12-13 11:30:12.596', 16.5, 1.25, 'lyft_plus'),
#  ('Lyft', 'Lux Black XL', 'Back Bay - Boston University', 1.69, '2018-12-13 11:30:12.596', 32.5, 1.25, 'lyft_luxsuv'),
#  ('Lyft', 'Shared', 'Back Bay - Boston University', 1.69, '2018-12-13 11:30:12.596', 7.0, 1.0, 'lyft_line'),
#  ('Lyft', 'Lux Black', 'Back Bay - Boston University', 1.61, '2018-11-29 00:32:07.821', 19.5, 1.0, 'lyft_lux'),
#  ('Lyft', 'Lux Black XL', 'Back Bay - Boston University', 1.61, '2018-11-29 00:32:07.821', 27.5, 1.0, 'lyft_luxsuv'),
#  ('Lyft', 'Lyft', 'Back Bay - Boston University', 1.61, '2018-12-14 08:55:10.183', 9.0, 1.0, 'lyft'),
#  ('Lyft', 'Lyft XL', 'Back Bay - Boston University', 1.61, '2018-12-14 08:55:10.183', 13.5, 1.0, 'lyft_plus'),
#  ('Lyft', 'Shared', 'Back Bay - Boston University', 1.61, '2018-12-14 08:55:10.183', 5.0, 1.0, 'lyft_line'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.61, '2018-12-14 08:55:10.183', 16.5, 1.0, 'lyft_premier'),
#  ('Lyft', 'Shared', 'Back Bay - Boston University', 1.6, '2018-12-16 00:45:12.480', 5.0, 1.0, 'lyft_line'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.6, '2018-12-16 00:45:12.480', 13.5, 1.0, 'lyft_premier'),
#  ('Lyft', 'Lux Black', 'Back Bay - Boston University', 1.6, '2018-12-16 00:45:12.480', 16.5, 1.0, 'lyft_lux'),
#  ('Lyft', 'Lux Black XL', 'Back Bay - Boston University', 1.6, '2018-12-15 06:05:13.538', 27.5, 1.0, 'lyft_luxsuv'),
#  ('Lyft', 'Lyft', 'Back Bay - Boston University', 1.6, '2018-12-15 06:05:13.538', 7.0, 1.0, 'lyft'),
#  ('Lyft', 'Lyft XL', 'Back Bay - Boston University', 1.6, '2018-12-15 06:05:13.538', 13.5, 1.0, 'lyft_plus'),
#  ('Lyft', 'Lux Black XL', 'Back Bay - Boston University', 1.59, '2018-12-02 23:43:02.404', 26.0, 1.0, 'lyft_luxsuv'),
#  ('Lyft', 'Lux Black', 'Back Bay - Boston University', 1.59, '2018-11-29 20:48:05.707', 16.5, 1.0, 'lyft_lux'),
#  ('Lyft', 'Lyft', 'Back Bay - Boston University', 1.59, '2018-12-18 14:10:04.607', 7.0, 1.0, 'lyft'),
#  ('Lyft', 'Lyft XL', 'Back Bay - Boston University', 1.59, '2018-11-26 14:32:09.623', 13.5, 1.0, 'lyft_plus'),
#  ('Lyft', 'Lux Black XL', 'Back Bay - Boston University', 1.59, '2018-11-28 09:56:08.006', 26.0, 1.0, 'lyft_luxsuv'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.59, '2018-12-16 12:20:11.275', 13.5, 1.0, 'lyft_premier'),
#  ('Lyft', 'Lux Black', 'Back Bay - Boston University', 1.59, '2018-11-28 12:26:25.630', 16.5, 1.0, 'lyft_lux'),
#  ('Lyft', 'Shared', 'Back Bay - Boston University', 1.59, '2018-12-18 06:55:03.280', 5.0, 1.0, 'lyft_line'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.59, '2018-12-16 05:55:13.334', 13.5, 1.0, 'lyft_premier'),
#  ('Lyft', 'Lux Black XL', 'Back Bay - Boston University', 1.59, '2018-12-17 21:45:14.486', 26.0, 1.0, 'lyft_luxsuv'),
#  ('Lyft', 'Lyft', 'Back Bay - Boston University', 1.59, '2018-11-28 17:11:07.832', 7.0, 1.0, 'lyft'),
#  ('Lyft', 'Lux Black', 'Back Bay - Boston University', 1.59, '2018-12-04 05:03:02.839', 16.5, 1.0, 'lyft_lux'),
#  ('Lyft', 'Lyft XL', 'Back Bay - Boston University', 1.59, '2018-11-26 12:47:09.637', 13.5, 1.0, 'lyft_plus'),
#  ('Lyft', 'Shared', 'Back Bay - Boston University', 1.59, '2018-11-27 01:17:23.162', 5.0, 1.0, 'lyft_line'),
#  ('Lyft', 'Lyft XL', 'Back Bay - Boston University', 1.59, '2018-11-30 11:52:59.345', 13.5, 1.0, 'lyft_plus'),
#  ('Lyft', 'Lux Black XL', 'Back Bay - Boston University', 1.59, '2018-11-30 11:52:59.345', 27.5, 1.0, 'lyft_luxsuv')]

# %%
# %%sql
# SELECT cab_type, name, "source" ||" - " || "destination" as route, distance, time_stamp, cast(price as float) as price, surge_multiplier, product_id
# FROM cabs
# WHERE price <> 'None' AND surge_multiplier <> 1
# ORDER BY route, cab_type, name, distance DESC
# Limit 100
# Out:
#  * sqlite://
# Done.
# [('Lyft', 'Lux', 'Back Bay - Boston University', 1.72, '2018-12-14 10:10:08.997', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.71, '2018-11-29 01:18:40.764', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.7, '2018-12-18 00:25:03.783', 19.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.69, '2018-11-28 16:26:07.939', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.59, '2018-12-01 17:07:56.318', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.58, '2018-11-27 11:30:22.385', 27.5, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.57, '2018-11-28 17:59:08.408', 26.0, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.57, '2018-12-17 01:35:10.629', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.57, '2018-11-28 16:31:26.473', 26.0, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.56, '2018-12-14 21:45:04.669', 22.5, 1.75, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.56, '2018-12-01 01:53:04.876', 26.0, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.56, '2018-11-28 15:17:07.491', 27.5, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.56, '2018-12-15 22:20:08.742', 26.0, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.56, '2018-11-29 13:03:01.118', 22.5, 1.75, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.56, '2018-11-30 13:32:56.142', 26.0, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.55, '2018-12-03 12:13:01.622', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.53, '2018-12-10 00:04:18.676', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.53, '2018-12-13 20:30:05.657', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.53, '2018-11-29 05:57:59.227', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.53, '2018-12-14 09:20:09.278', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.53, '2018-12-02 15:13:01.488', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.52, '2018-11-28 22:38:08.109', 22.5, 1.75, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.52, '2018-11-30 18:22:57.656', 27.5, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.52, '2018-11-29 03:19:16.535', 27.5, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.52, '2018-11-30 13:42:58.001', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.52, '2018-12-18 16:05:08.584', 22.5, 1.75, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.52, '2018-11-28 17:11:07.947', 27.5, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.51, '2018-12-03 08:38:00.748', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.51, '2018-11-28 11:47:07.968', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.51, '2018-11-29 21:26:53.294', 19.5, 1.5, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.51, '2018-11-27 21:09:22.088', 22.5, 1.75, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.51, '2018-11-28 00:30:21.934', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.51, '2018-11-27 23:21:21.926', 26.0, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.51, '2018-12-02 05:28:06.259', 22.5, 1.75, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.51, '2018-12-16 11:15:11.572', 26.0, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.51, '2018-12-14 09:35:08.937', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.51, '2018-12-01 20:22:56.201', 19.5, 1.5, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.51, '2018-12-17 10:50:07.164', 19.5, 1.5, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.51, '2018-11-26 13:05:10.205', 22.5, 1.75, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.51, '2018-12-14 10:25:16.297', 26.0, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.51, '2018-11-30 06:38:00.600', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.51, '2018-11-27 13:09:23.624', 27.5, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.51, '2018-12-02 08:47:56.398', 22.5, 1.75, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.5, '2018-11-28 22:08:40.260', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.5, '2018-12-15 03:40:15.195', 22.5, 1.75, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.5, '2018-12-03 17:47:57.527', 27.5, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.5, '2018-12-15 06:50:11.043', 27.5, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.5, '2018-12-14 15:35:08.366', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.5, '2018-12-02 17:58:01.663', 26.0, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.49, '2018-12-03 02:33:03.398', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.49, '2018-11-28 15:21:25.743', 27.5, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.49, '2018-12-17 02:40:07.211', 19.5, 1.5, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.49, '2018-11-26 23:36:14.098', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.48, '2018-12-14 17:55:05.184', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.47, '2018-12-15 22:55:09.528', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.47, '2018-12-16 13:05:14.701', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.47, '2018-12-01 13:42:57.121', 19.5, 1.5, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.47, '2018-12-13 12:30:10.350', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.47, '2018-11-27 14:51:22.337', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.47, '2018-11-27 20:21:23.006', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.47, '2018-11-29 16:13:07.198', 19.5, 1.5, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.47, '2018-12-10 00:48:27.537', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.47, '2018-12-16 03:50:13.265', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.47, '2018-11-29 02:24:22.478', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.47, '2018-12-01 09:37:55.866', 22.5, 1.75, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.47, '2018-12-13 22:55:14.155', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.46, '2018-12-15 17:45:09.390', 26.0, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.46, '2018-12-15 04:55:13.265', 19.5, 1.5, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.46, '2018-11-28 10:06:23.843', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.46, '2018-11-29 16:18:04.525', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.46, '2018-12-13 07:30:08.210', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.46, '2018-11-28 19:50:08.302', 19.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.46, '2018-12-14 02:15:09.829', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.46, '2018-12-01 01:03:11.513', 22.5, 1.75, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.46, '2018-12-13 12:05:12.240', 26.0, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.46, '2018-12-16 00:55:09.583', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.46, '2018-12-02 15:53:03.350', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.46, '2018-12-16 07:40:14.027', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.46, '2018-11-28 13:26:26.240', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.46, '2018-12-14 18:10:03.598', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.46, '2018-11-30 14:13:05.782', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.45, '2018-11-27 07:21:23.256', 19.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.45, '2018-12-13 08:50:06.389', 26.0, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.45, '2018-11-27 17:33:22.472', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.45, '2018-11-27 13:42:22.339', 22.5, 1.5, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.45, '2018-12-13 23:55:08.068', 26.0, 1.75, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.45, '2018-11-29 21:03:02.782', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.45, '2018-11-29 13:47:57.643', 30.0, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.45, '2018-12-03 10:38:03.934', 27.5, 2.0, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.45, '2018-12-16 06:40:14.016', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.45, '2018-12-14 18:35:10.698', 22.5, 1.5, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.45, '2018-12-17 10:00:09.214', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.45, '2018-12-03 09:28:02.123', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.44, '2018-12-18 06:30:13.552', 22.5, 1.5, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.44, '2018-11-29 22:38:02.582', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.44, '2018-12-14 22:25:17.587', 22.5, 1.75, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.44, '2018-12-03 23:18:05.165', 19.5, 1.5, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.44, '2018-11-30 07:07:56.974', 22.5, 1.5, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.44, '2018-12-01 14:18:03.824', 16.5, 1.25, 'lyft_premier'),
#  ('Lyft', 'Lux', 'Back Bay - Boston University', 1.44, '2018-12-15 09:35:09.550', 16.5, 1.25, 'lyft_premier')]

# %% [markdown]
# **6. Does the weather have any effect on the pricing**

# %%
# %%sql
# SELECT cabs.time_stamp, cabs.time_stamp, weather.time_stamp
# FROM cabs, weather
# WHERE cabs.strftime('%Y-%m-%d %H:%M:%f', time_stamp) = weather.strftime('%Y-%m-%d %H:%M:%f', time_stamp)
# LIMIT 10
# Out:
#  * sqlite://
# (sqlite3.OperationalError) near "(": syntax error
# [SQL: SELECT cabs.time_stamp, cabs.time_stamp, weather.time_stamp
# FROM cabs, weather
# WHERE cabs.strftime('%Y-%m-%d %H:%M:%f', time_stamp) = weather.strftime('%Y-%m-%d %H:%M:%f', time_stamp)
# LIMIT 10]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# A </font></em>

# %% [markdown]
# ---

# %%
# 

# %%sql
SELECT cab_type, name, "source" ||" - " || "destination" as route, distance, date(cabs.time_stamp) as mydate, time(cabs.time_stamp) as mytime, cast(price as float) as price, surge_multiplier, product_id, weather.location
FROM cabs, weather
left join weather on  weather.location = cabs.source
ORDER BY route, cab_type, name, distance, mydate DESC
Limit 100
# Out:
#  * sqlite://
# (sqlite3.OperationalError) ambiguous column name: weather.location
# [SQL: SELECT cab_type, name, "source" ||" - " || "destination" as route, distance, date(cabs.time_stamp) as mydate, time(cabs.time_stamp) as mytime, cast(price as float) as price, surge_multiplier, product_id, weather.location
# FROM cabs, weather
# left join weather on  weather.location = cabs.source
# ORDER BY route, cab_type, name, distance, mydate DESC
# Limit 100]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# ## Step 4. Report

# %% [markdown]
# 1. The weather dataset has 6,276 records and 8 fields (features) while the cabsrides recordset has 693,071 records and 10 fields.
#
# 2. Data in these recordsets was collected between 2018-11-26 03:40:46 and 2018-12-18 19:15:10 for the cab rides and between 2018-11-26 03:40:44 and 2018-12-18 18:45:02 for the weather. Any insights communicated therefore are based on this period of business transactions.
#
# 3. From this check of null values, we notice that:
#
# - Out of 6,273 records in the weather dataset, we have 5,382 records for days / time when there was no rain. we update all the NULL values to zeros in the rain column for these records to mean there was 0 mm of rain (it didn't rain)
# - The price feature of cab rides registered null values of 55,095 entries. Pricing is one of the most important feature of the dataset in this analysis and therefore these will be dropped as they represent only 14% of all Uber records in the dataset.
#
# 4. Uber cars are preferred over Lyft ones at a share of 51.81% to 48.19% of the sampled rides respectively.
#
# 5. From the above exploration, we notice the following:
#
# - The highest price for a ride recorded is by Lyft for the journey between Financial District and Fenway at a cost of `$97.5` (with a multiplier of 2.0) on 2nd Dec 2018.
# - The lowest price for a ride recorded is also by Lyft for the journey between Boston University and Back Bay at a cost of `$2.5` (default price, no multiplier) on 28th Dec 2018.
# - The average cost for the rides is `$16.54`.
#
# 6. The average pricing for each route represented in the sample dataset is given in the analysis and will help the incoming ride company to estimate the pricing between different sources and destinations.
#
# 7. Regardless of the distance, 94% of the highest rates (Top 100) for the rides were recorded by lyft. Also notice that among the top 100 rides in terms of cost, all the Lyft rides' prices were hiked some to double double the cost. This send another probing question... does Uber ever increase its prices?... lets find out next.
#
# - Interestingly, we notice that Uber does not increase its prices for the rides at all. This is brought out by the fact that the surge_multiplier is always 1. However, Lyft on the other hand has some rides with normal fare and others with hiked charges with between 1.25 to 3 times normal fare. The incoming ride company will then need to see which model works best for them.
#
# 8. We notice that the only routes where the prices are hiked by up to 3 times are only 6. and this happens only with the Lyft and Lyft Plus products of the company. The incoming company needs to know the special feature that is along these routes for proper placement.
